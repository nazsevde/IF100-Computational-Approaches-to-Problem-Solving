# %%
databases = input("Please enter the database: ")   
username = input("Please enter the username: ")

for x in username.split():
   mid = len(username) // 2
   x[0:mid]

for i in username.split():
   after_mid = len(username) - mid
   i[mid:len(username)]
encrytpted_username = x[mid:len(username)] + i[0:mid][-1].lower() + i[0:mid]

if encrytpted_username in databases:
 for i in range(5):
   if databases.split(",")[i].split(":")[0] == encrytpted_username:
    if int(databases.split(",")[i].split(":")[3])/int(databases.split(",")[i].split(":")[2]) >= 10:
     print("There is a high chance that", username, "may be a bot!")
    else:
     interested_type = input("Please enter the type you are interested in: ")

     if interested_type in databases.split(",")[i].split(":")[1].split("-"):
       print("It is safe to accept the following request of ", username, ".", sep="")
     else:
       print("Interests do not match with ", username, "!")
else:
  print("Username does not exist!")
# Out:
# Please enter the database: oodfDlf:food-music:1037:705,efulpFhop:travel:60:1124,wisemMUSM:food:100:1000,ulleapfhelpf:travel:10809:107,lexiblefstylef:art:509:320
# Please enter the username: styleflexible
# Please enter the type you are interested in: food
# Interests do not match with  styleflexible !

# %% [markdown]
# ....
